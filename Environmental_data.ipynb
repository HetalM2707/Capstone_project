# %% [markdown]
# ## Importing packages

# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np
import psycopg2 # needed to get database exception errors when uploading dataframe
import requests # package for getting data from the web
from zipfile import * # package for unzipping zip files

# %% [markdown]
# ## Reading data files

# %% [markdown]
# ### New York

# %%
df_NY_18_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2018/ad_NY_18_CO.csv', delimiter=',')
df_NY_18_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2018/ad_NY_18_NO2.csv', delimiter=',')
df_NY_18_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2018/ad_NY_18_Oz.csv', delimiter=',')
df_NY_18_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2018/ad_NY_18_PM2.5.csv', delimiter=',')
df_NY_18_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2018/ad_NY_18_PM10.csv', delimiter=',')
df_NY_18_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2018/ad_NY_18_SO2.csv', delimiter=',')

# %%
df_NY_19_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2019/ad_Ny_19_Co.csv', delimiter=',')
df_NY_19_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2019/ad_Ny_19_NO2.csv', delimiter=',')
df_NY_19_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2019/ad_Ny_19_Oz.csv', delimiter=',')
df_NY_19_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2019/ad_Ny_19_PM2.5.csv', delimiter=',')
df_NY_19_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2019/ad_Ny_19_PM10.csv', delimiter=',')
df_NY_19_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2019/ad_Ny_19_SO2.csv', delimiter=',')

# %%
df_NY_20_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/New York 2020 the state data/ad_Newyork_2020_CO.csv', delimiter=',')
df_NY_20_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/New York 2020 the state data/ad_viz_plotval_data_NO.csv', delimiter=',')
df_NY_20_Oz= pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/New York 2020 the state data/ad_viz_plotval_data_Oz.csv', delimiter=',')
df_NY_20_PM2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/New York 2020 the state data/ad_viz_plotval_data_pm2.5.csv', delimiter=',')
df_NY_20_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/New York 2020 the state data/ad_viz_plotval_data_PM10.csv', delimiter=',')
df_NY_20_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/New York 2020 the state data/ad_viz_plotval_data_SO2.csv', delimiter=',')

# %%
df_NY_21_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2021/ad_Ny_21_Co.csv', delimiter=',')
df_NY_21_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2021/ad_Ny_21_NO2.csv', delimiter=',')
df_NY_21_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2021/ad_Ny_21_Oz.csv', delimiter=',')
df_NY_21_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2021/ad_Ny_21_PM2.5.csv', delimiter=',')
df_NY_21_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2021/ad_NY_21_pm10.csv', delimiter=',')
df_NY_21_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2021/ad_NY_21_SO2.csv', delimiter=',')

# %%
df_NY_22_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2022/ad_Ny_22_Co.csv', delimiter=',')
df_NY_22_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2022/ad_Ny_22_NO2.csv', delimiter=',')
df_NY_22_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2022/ad_Ny_22_Oz.csv', delimiter=',')
df_NY_22_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2022/ad_Ny_22_PM2.5.csv', delimiter=',')
df_NY_22_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2022/ad_Ny_22_PM10.csv', delimiter=',')
df_NY_22_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/New York/2022/ad_Ny_22_SO2.csv', delimiter=',')

# %% [markdown]
# ### California data

# %%
df_CA_18_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2018/ad_ca_18_CO.csv', delimiter=',')
df_CA_18_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2018/ad_ca_18_NO2.csv', delimiter=',')
df_CA_18_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2018/ad_ca_18_Oz.csv', delimiter=',')
df_CA_18_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2018/ad_ca-18_PM2.5.csv', delimiter=',')
df_CA_18_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2018/ad_ca_18_PM10.csv', delimiter=',')
df_CA_18_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2018/ad_ca_18_SO2.csv', delimiter=',')

# %%
df_CA_19_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2019/ad_ca_19_CO.csv', delimiter=',')
df_CA_19_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2019/ad_ca_19_NO2.csv', delimiter=',')
df_CA_19_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2019/ad_ca_19_Oz.csv', delimiter=',')
df_CA_19_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2019/ad_ca_19_PM2.5.csv', delimiter=',')
df_CA_19_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2019/ad_ca_19_PM10.csv', delimiter=',')
df_CA_19_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2019/ad_ca_19_SO2.csv', delimiter=',')

# %%
df_CA_20_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2020/ad_california_20_CO.csv', delimiter=',')
df_CA_20_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2020/ad_california_20_N02.csv', delimiter=',')
df_CA_20_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2020/ad_california_20_Oz.csv', delimiter=',')
df_CA_20_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2020/ad_california_20_PM2.5.csv', delimiter=',')
df_CA_20_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2020/ad_california_20_PM10.csv', delimiter=',')
df_CA_20_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2020/ad_california_20_SO2.csv', delimiter=',')

# %%
df_CA_21_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2021/ad_california_21_CO.csv', delimiter=',')
df_CA_21_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2021/ad_california_21_NO2.csv', delimiter=',')
df_CA_21_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2021/ad_california_21_OZ.csv', delimiter=',')
df_CA_21_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2021/ad_california_21_PM2.5.csv', delimiter=',')
df_CA_21_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2021/ad_california_21_PM10.csv', delimiter=',')
df_CA_21_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2021/ad_california_21_SO2.csv', delimiter=',')

# %%
df_CA_22_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2022/ad_california_22_CO.csv', delimiter=',')
df_CA_22_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2022/ad_california_22_NO2.csv', delimiter=',')
df_CA_22_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2022/ad_california_22_Oz.csv', delimiter=',')
df_CA_22_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2022/ad_california_22_PM2.5.csv', delimiter=',')
df_CA_22_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2022/ad_california_22_PM10.csv', delimiter=',')
df_CA_22_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/California/2022/ad_california_22_SO2.csv', delimiter=',')

# %% [markdown]
# ### Illinois data

# %%
df_ILL_18_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2018/ad_illinois_18_CO.csv', delimiter=',')
df_ILL_18_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2018/ad_illinois_18_NO2.csv', delimiter=',')
df_ILL_18_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2018/ad_illinois_18_OZ.csv', delimiter=',')
df_ILL_18_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2018/ad_illinois_18_PM2.5.csv', delimiter=',')
df_ILL_18_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2018/ad_illinois_18_PM10.csv', delimiter=',')
df_ILL_18_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2018/ad_illinois_18_SO2.csv', delimiter=',')

# %%
df_ILL_19_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2019/ad_illinois_19_CO.csv', delimiter=',')
df_ILL_19_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2019/ad_illinois_19_NO2.csv', delimiter=',')
df_ILL_19_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2019/ad_illinois_19_OZ.csv', delimiter=',')
df_ILL_19_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2019/ad_illinois_19_PM2.5.csv', delimiter=',')
df_ILL_19_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2019/ad_illinois_19_PM10.csv', delimiter=',')
df_ILL_19_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2019/ad_illinois_19_SO2.csv', delimiter=',')

# %%
df_ILL_20_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2020/ad_illinois_20_CO.csv', delimiter=',')
df_ILL_20_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2020/ad_illinois_20_NO2.csv', delimiter=',')
df_ILL_20_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2020/ad_illinois_20_OZ.csv', delimiter=',')
df_ILL_20_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2020/ad_illinois_20_PM2.5.csv', delimiter=',')
df_ILL_20_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2020/ad_illinois_20_PM10.csv', delimiter=',')
df_ILL_20_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2020/ad_illinois_So2.csv', delimiter=',')

# %%
df_ILL_21_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2021/ad_Ilinois_21_CO.csv', delimiter=',')
df_ILL_21_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2021/ad_illinois_21_NO2.csv', delimiter=',')
df_ILL_21_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2021/ad_illinois_21_Oz.csv', delimiter=',')
df_ILL_21_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2021/ad_illinois_21_PM2.5.csv', delimiter=',')
df_ILL_21_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2021/ad_illinois_21_PM10.csv', delimiter=',')
df_ILL_21_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2021/ad_illinois_21_SO2.csv', delimiter=',')

# %%
df_ILL_22_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2022/ad_illinois_22_Co.csv', delimiter=',')
df_ILL_22_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2022/ad_illinois_22_NO2.csv', delimiter=',')
df_ILL_22_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2022/ad_illinois_22_Oz.csv', delimiter=',')
df_ILL_22_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2022/ad_iilinois_22_PM2.5.csv', delimiter=',')
df_ILL_22_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2022/ad_iilinois_22_PM10.csv', delimiter=',')
df_ILL_22_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/illinois/2022/ad_illinois_22_SO2.csv', delimiter=',')

# %% [markdown]
# ### Pennsylvania data

# %%
df_Penn_18_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2018/ad_Penn_18_CO.csv', delimiter=',')
df_Penn_18_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2018/ad_Penn_18_NO2.csv', delimiter=',')
df_Penn_18_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2018/ad_Penn_18_Oz.csv', delimiter=',')
df_Penn_18_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2018/ad_Penn_18_PM2.5.csv', delimiter=',')
df_Penn_18_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2018/ad_Penn_18_PM10.csv', delimiter=',')
df_Penn_18_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2018/ad_Penn_18_SO2.csv', delimiter=',')

# %%
df_Penn_19_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2019/ad_Penn_19_CO.csv', delimiter=',')
df_Penn_19_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2019/ad_Penn_19_NO2.csv', delimiter=',')
df_Penn_19_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2019/ad_Penn_19_Oz.csv', delimiter=',')
df_Penn_19_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2019/ad_Penn_19_PM2.5.csv', delimiter=',')
df_Penn_19_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2019/ad_Penn_19_PM10.csv', delimiter=',')
df_Penn_19_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2019/ad_Penn_19_SO2.csv', delimiter=',')

# %%
df_Penn_20_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2020/ad_Penn_20_CO.csv', delimiter=',')
df_Penn_20_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2020/ad_Penn_20_NO2.csv', delimiter=',')
df_Penn_20_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2020/ad_Penn_20_OZ.csv', delimiter=',')
df_Penn_20_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2020/ad_Penn_20_PM2.5.csv', delimiter=',')
df_Penn_20_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2020/ad_Penn_20_PM10.csv', delimiter=',')
df_Penn_20_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2020/ad_Penn_20_SO2.csv', delimiter=',')

# %%
df_Penn_21_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2021/ad_Penn_21_CO.csv', delimiter=',')
df_Penn_21_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2021/ad_Penn_21_NO2.csv', delimiter=',')
df_Penn_21_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2021/ad_Penn_21_Oz.csv', delimiter=',')
df_Penn_21_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2021/ad_Penn_21_PM2.5.csv', delimiter=',')
df_Penn_21_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2021/ad_Penn_21_PM10.csv', delimiter=',')
df_Penn_21_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2021/ad_Penn_21_SO2.csv', delimiter=',')

# %%
df_Penn_22_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2022/ad_Penn_22_CO.csv', delimiter=',')
df_Penn_22_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2022/ad_Penn_22_NO2.csv', delimiter=',')
df_Penn_22_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2022/ad_Penn_22_OZ.csv', delimiter=',')
df_Penn_22_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2022/ad_Penn_22_PM2.5.csv', delimiter=',')
df_Penn_22_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2022/ad_Penn_22_PM10.csv', delimiter=',')
df_Penn_22_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Pennsylvania/2022/ad_Penn_22_SO2.csv', delimiter=',')

# %% [markdown]
# ### Texas data

# %%
df_Tx_18_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2018/ad_Tx_18_CO.csv', delimiter=',')
df_Tx_18_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2018/ad_Tx_18_NO2.csv', delimiter=',')
df_Tx_18_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2018/ad_Tx_18_OZ.csv', delimiter=',')
df_Tx_18_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2018/ad_Tx_18_PM2.5.csv', delimiter=',')
df_Tx_18_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2018/ad_Tx_18_PM10.csv', delimiter=',')
df_Tx_18_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data//Texas/2018/ad_Tx_18_SO2.csv', delimiter=',')

# %%
df_Tx_19_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2019/ad_Tx_19_CO.csv', delimiter=',')
df_Tx_19_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2019/ad_Tx_19_NO2.csv', delimiter=',')
df_Tx_19_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2019/ad_Tx_19_Oz.csv', delimiter=',')
df_Tx_19_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2019/ad_Tx_19_PM2.5.csv', delimiter=',')
df_Tx_19_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2019/ad_Tx_19_PM10.csv', delimiter=',')
df_Tx_19_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data//Texas/2019/ad_Tx_19_SO2.csv', delimiter=',')

# %%
df_Tx_20_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2020/ad_Tx_20_CO.csv', delimiter=',')
df_Tx_20_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2020/ad_Tx_20_NO2.csv', delimiter=',')
df_Tx_20_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2020/ad_Tx_20_Oz.csv', delimiter=',')
df_Tx_20_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2020/ad_Tx_20_PM2.5.csv', delimiter=',')
df_Tx_20_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2020/ad_Tx_20_PM10.csv', delimiter=',')
df_Tx_20_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data//Texas/2020/ad_Tx_20_SO2.csv', delimiter=',')

# %%
df_Tx_21_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2021/ad_Tx_21_CO.csv', delimiter=',')
df_Tx_21_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2021/ad_Tx_21_NO2.csv', delimiter=',')
df_Tx_21_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2021/ad_Tx_21_Oz.csv', delimiter=',')
df_Tx_21_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2021/ad_Tx_21_PM2.5.csv', delimiter=',')
df_Tx_21_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2021/ad_Tx_21_PM10.csv', delimiter=',')
df_Tx_21_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data//Texas/2021/ad_Tx_21_SO2.csv', delimiter=',')

# %%
df_Tx_22_CO = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2022/ad_Tx_22_CO.csv', delimiter=',')
df_Tx_22_NO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2022/ad_Tx_22_NO2.csv', delimiter=',')
df_Tx_22_Oz = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2022/ad_Tx_22_Oz.csv', delimiter=',')
df_Tx_22_PM25 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2022/ad_Tx_22_PM2.5.csv', delimiter=',')
df_Tx_22_PM10 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data/Texas/2022/ad_Tx_22_PM10.csv', delimiter=',')
df_Tx_22_SO2 = pd.read_csv('C:/Hetal/hetal/nf/capstone/data/state wise data//Texas/2022/ad_Tx_22_SO2.csv', delimiter=',')

# %% [markdown]
# #### Merging the data frames

# %%
NY_CO = pd.concat([df_NY_18_CO, df_NY_19_CO, df_NY_20_CO, df_NY_21_CO, df_NY_22_CO], ignore_index= True)

# %%
NY_NO2 = pd.concat([df_NY_18_NO2, df_NY_19_NO2, df_NY_20_NO2, df_NY_21_NO2, df_NY_22_NO2], ignore_index= True)
NY_OZ = pd.concat([df_NY_18_Oz, df_NY_19_Oz, df_NY_20_Oz, df_NY_21_Oz, df_NY_22_Oz], ignore_index= True)
NY_PM10 = pd.concat([df_NY_18_PM10, df_NY_19_PM10, df_NY_20_PM10, df_NY_21_PM10, df_NY_22_PM10], ignore_index= True)
NY_PM25 = pd.concat([df_NY_18_PM25, df_NY_19_PM25, df_NY_20_PM2, df_NY_21_PM25, df_NY_22_PM25], ignore_index= True)
NY_SO2 = pd.concat([df_NY_18_SO2, df_NY_19_SO2, df_NY_20_SO2, df_NY_21_SO2, df_NY_22_SO2], ignore_index= True)

# %%
CA_CO = pd.concat([df_CA_18_CO, df_CA_19_CO, df_CA_20_CO, df_CA_21_CO, df_CA_22_CO], ignore_index= True)
CA_NO2 = pd.concat([df_CA_18_NO2, df_CA_19_NO2, df_CA_20_NO2, df_CA_21_NO2, df_CA_22_NO2], ignore_index= True)
CA_OZ = pd.concat([df_CA_18_Oz, df_CA_19_Oz, df_CA_20_Oz, df_CA_21_Oz, df_CA_22_Oz], ignore_index= True)
CA_PM10 = pd.concat([df_CA_18_PM10, df_CA_19_PM10, df_CA_20_PM10, df_CA_21_PM10, df_CA_22_PM10], ignore_index= True)
CA_PM25 = pd.concat([df_CA_18_PM25, df_CA_19_PM25, df_CA_20_PM25, df_CA_21_PM25, df_CA_22_PM25], ignore_index= True)
CA_SO2_final = pd.concat([df_CA_18_SO2, df_CA_19_SO2, df_CA_20_SO2, df_CA_21_SO2, df_CA_22_SO2], ignore_index= True)

# %%
Ill_CO = pd.concat([df_ILL_18_CO, df_ILL_19_CO, df_ILL_20_CO, df_ILL_21_CO, df_ILL_22_CO], ignore_index= True)
Ill_NO2 = pd.concat([df_ILL_18_NO2, df_ILL_19_NO2, df_ILL_20_NO2, df_ILL_21_NO2, df_ILL_22_NO2], ignore_index= True)
Ill_OZ = pd.concat([df_ILL_18_Oz, df_ILL_19_Oz, df_ILL_20_Oz, df_ILL_21_Oz, df_ILL_22_Oz], ignore_index= True)
Ill_PM10 = pd.concat([df_ILL_18_PM10, df_ILL_19_PM10, df_ILL_20_PM10, df_ILL_21_PM10, df_ILL_22_PM10], ignore_index= True)
Ill_PM25 = pd.concat([df_ILL_18_PM25, df_ILL_19_PM25, df_ILL_20_PM25, df_ILL_21_PM25, df_ILL_22_PM25], ignore_index= True)
Ill_SO2 = pd.concat([df_ILL_18_SO2, df_ILL_19_SO2, df_ILL_20_SO2, df_ILL_21_SO2, df_ILL_22_SO2], ignore_index= True)

# %%
Penn_CO = pd.concat([df_Penn_18_CO, df_Penn_19_CO, df_Penn_20_CO, df_Penn_21_CO, df_Penn_22_CO], ignore_index=True)
Penn_NO2 = pd.concat([df_Penn_18_NO2, df_Penn_19_NO2, df_Penn_20_NO2, df_Penn_21_NO2,df_Penn_22_NO2], ignore_index=True)
Penn_OZ = pd.concat([df_Penn_18_Oz, df_Penn_19_Oz, df_Penn_20_Oz, df_Penn_21_Oz, df_Penn_22_Oz], ignore_index=True)
Penn_PM10 = pd.concat([df_Penn_18_PM10, df_Penn_19_PM10, df_Penn_20_PM10, df_Penn_21_PM10, df_Penn_22_PM10], ignore_index=True)
Penn_PM25= pd.concat([df_Penn_18_PM25, df_Penn_19_PM25, df_Penn_20_PM25, df_Penn_21_PM25, df_Penn_22_PM25], ignore_index=True)
Penn_SO2= pd.concat([df_Penn_18_SO2, df_Penn_19_SO2, df_Penn_20_SO2, df_Penn_21_SO2, df_Penn_22_SO2], ignore_index=True)

# %%
Texas_CO = pd.concat([df_Tx_18_CO, df_Tx_19_CO, df_Tx_20_CO, df_Tx_21_CO, df_Tx_22_CO], ignore_index=True)
Texas_NO2 = pd.concat([df_Tx_18_NO2, df_Tx_19_NO2, df_Tx_20_NO2, df_Tx_21_NO2,df_Tx_22_NO2], ignore_index=True)
Texas_OZ = pd.concat([df_Tx_18_Oz, df_Tx_19_Oz, df_Tx_20_Oz, df_Tx_21_Oz, df_Tx_22_Oz], ignore_index=True)
Texas_PM10 = pd.concat([df_Tx_18_PM10, df_Tx_19_PM10, df_Tx_20_PM10, df_Tx_21_PM10, df_Tx_22_PM10], ignore_index=True)
Texas_PM25= pd.concat([df_Tx_18_PM25, df_Tx_19_PM25, df_Tx_20_PM25, df_Tx_21_PM25, df_Tx_22_PM25], ignore_index=True)
Texas_SO2= pd.concat([df_Tx_18_SO2, df_Tx_19_SO2, df_Tx_20_SO2, df_Tx_21_SO2, df_Tx_22_SO2], ignore_index=True)

# %% [markdown]
# ### Understanding the data and data cleansing

# %%
Texas_CO.head(5)
# Out:
#          Date Source    Site ID  POC  Daily Max 8-hour CO Concentration Units  \
# 0  01/01/2018    AQS  480291069    1                                0.3   ppm
# 1  01/02/2018    AQS  480291069    1                                0.4   ppm
# 2  01/03/2018    AQS  480291069    1                                0.7   ppm
# 3  01/04/2018    AQS  480291069    1                                0.8   ppm
# 4  01/05/2018    AQS  480291069    1                                0.4   ppm
#
#    Daily AQI Value            Local Site Name  Daily Obs Count  \
# 0                3  San Antonio Interstate 35               19
# 1                5  San Antonio Interstate 35               24
# 2                8  San Antonio Interstate 35               24
# 3                9  San Antonio Interstate 35               24
# 4                5  San Antonio Interstate 35               24
#
#    Percent Complete  ...  AQS Parameter Description Method Code  CBSA Code  \
# ...

# %%
Penn_CO.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17319 entries, 0 to 17318
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               17319 non-null  object
#  1   Source                             17319 non-null  object
#  2   Site ID                            17319 non-null  int64
#  3   POC                                17319 non-null  int64
#  4   Daily Max 8-hour CO Concentration  17319 non-null  float64
#  5   Units                              17319 non-null  object
#  6   Daily AQI Value                    17319 non-null  int64
#  7   Local Site Name                    17319 non-null  object
#  8   Daily Obs Count                    17319 non-null  int64
#  9   Percent Complete                   17319 non-null  float64
#  10  AQS Parameter Code                 17319 non-null  int64
# ...

# %%
Texas_CO.describe()
# Out:
#             Site ID           POC  Daily Max 8-hour CO Concentration  \
# count  2.030800e+04  20308.000000                       20308.000000
# mean   4.823407e+08      1.407426                           0.388532
# std    1.390622e+06      0.644111                           0.267478
# min    4.802911e+08      1.000000                          -0.200000
# 25%    4.814100e+08      1.000000                           0.200000
# 50%    4.820110e+08      1.000000                           0.300000
# 75%    4.830910e+08      2.000000                           0.500000
# max    4.847900e+08      3.000000                           3.900000
#
#        Daily AQI Value  Daily Obs Count  Percent Complete  AQS Parameter Code  \
# count     20308.000000     20308.000000      20308.000000             20308.0
# mean          4.346021        23.525556         98.028117             42101.0
# std           3.161760         2.169683          9.022738                 0.0
# ...

# %%
Texas_CO.isnull().sum()
# Out:
# Date                                 0
# Source                               0
# Site ID                              0
# POC                                  0
# Daily Max 8-hour CO Concentration    0
# Units                                0
# Daily AQI Value                      0
# Local Site Name                      0
# Daily Obs Count                      0
# Percent Complete                     0
# AQS Parameter Code                   0
# AQS Parameter Description            0
# Method Code                          2
# CBSA Code                            0
# CBSA Name                            0
# State FIPS Code                      0
# State                                0
# County FIPS Code                     0
# County                               0
# Site Latitude                        0
# Site Longitude                       0
# dtype: int64

# %%
NY_CO.isnull().sum()
# Out:
# Date                                 0
# Source                               0
# Site ID                              0
# POC                                  0
# Daily Max 8-hour CO Concentration    0
# Units                                0
# Daily AQI Value                      0
# Local Site Name                      0
# Daily Obs Count                      0
# Percent Complete                     0
# AQS Parameter Code                   0
# AQS Parameter Description            0
# Method Code                          0
# CBSA Code                            0
# CBSA Name                            0
# State FIPS Code                      0
# State                                0
# County FIPS Code                     0
# County                               0
# Site Latitude                        0
# Site Longitude                       0
# dtype: int64

# %% [markdown]
# ### Merging the data - final merge

# %%
CO_state = pd.concat([NY_CO, CA_CO, Penn_CO, Texas_CO, Ill_CO], ignore_index= True)
NO2_state = pd.concat([NY_NO2, CA_NO2, Penn_NO2, Texas_NO2, Ill_NO2], ignore_index= True)
OZ_state = pd.concat([NY_OZ, CA_OZ, Penn_OZ, Texas_OZ, Ill_OZ], ignore_index=True)
PM_10_state = pd.concat([NY_PM10, CA_PM10, Penn_PM10, Texas_PM10, Ill_PM10], ignore_index=True)
PM_25_state = pd.concat([NY_PM25, CA_PM25,Penn_PM25, Texas_PM25, Ill_PM25], ignore_index=True)
SO2_state = pd.concat([NY_SO2, CA_SO2_final, Penn_SO2,Texas_SO2, Ill_SO2], ignore_index=True)

# %%
NO2_state.drop(columns=['Source','Site ID', 'POC','Percent Complete', 'AQS Parameter Code','Percent Complete', 'AQS Parameter Code','Method Code', 'CBSA Code', 'CBSA Name', 'State FIPS Code','County FIPS Code'], inplace=True)
CO_state.drop(columns=['Site ID', 'POC','County FIPS Code','Source', 'Method Code', 'CBSA Code', 'CBSA Name', 'State FIPS Code','County FIPS Code','Percent Complete','AQS Parameter Code','County FIPS Code'], inplace=True)
OZ_state.drop(columns=['Site ID', 'Source', 'Method Code', 'CBSA Code', 'CBSA Name', 'State FIPS Code',], inplace=True)
PM_10_state.drop(columns=['Site ID','POC','County FIPS Code', 'Source', 'Method Code', 'CBSA Code', 'CBSA Name', 'State FIPS Code','Percent Complete','AQS Parameter Code'], inplace=True)
PM_25_state.drop(columns=['Site ID','POC','County FIPS Code', 'Source', 'Method Code', 'CBSA Code', 'CBSA Name', 'State FIPS Code','Percent Complete','AQS Parameter Code'], inplace=True)
SO2_state.drop(columns=['Source','Site ID','POC','Percent Complete','AQS Parameter Code','Method Code', 'CBSA Code', 'CBSA Name', 'State FIPS Code','County FIPS Code'], inplace=True)

# %%
NO2_state.columns = NO2_state.columns.str.lower().str.replace(' ', '_')
CO_state.columns = CO_state.columns.str.lower().str.replace(' ', '_')
OZ_state.columns = OZ_state.columns.str.lower().str.replace(' ', '_')
PM_10_state.columns = PM_10_state.columns.str.lower().str.replace(' ', '_')
PM_25_state.columns = PM_25_state.columns.str.lower().str.replace(' ', '_')
SO2_state.columns = SO2_state.columns.str.lower().str.replace(' ', '_')

# %%
NO2_state['date'] = pd.to_datetime(NO2_state['date'], format='mixed')
SO2_state['date'] = pd.to_datetime(SO2_state['date'], format='mixed')
CO_state['date'] = pd.to_datetime(CO_state['date'], format='mixed')
PM_10_state['date'] = pd.to_datetime(PM_10_state['date'], format='mixed')
PM_25_state['date'] = pd.to_datetime(PM_25_state['date'], format='mixed')
OZ_state['date'] = pd.to_datetime(OZ_state['date'], format='mixed')

# %% [markdown]
# ### Uploading the dataset to DBeaver (SQL)

# %%
import pandas as pd
import numpy as np
import psycopg2 # needed to get database exception errors when uploading dataframe
import requests # package for getting data from the web
from zipfile import * # package for unzipping zip files
import sqlalchemy

# %%
import os
import dotenv

# %%
from dotenv import dotenv_values

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
def get_sql_config():
    '''
        Function loads credentials from .env file and
        returns a dictionary containing the data needed for sqlalchemy.create_engine()
    '''
    needed_keys = ['host', 'port', 'database','user','password']
    dotenv_dict = dotenv_values(".env")
    sql_config = {key:dotenv_dict[key] for key in needed_keys if key in dotenv_dict}
    return sql_config

# %%
sql_config = get_sql_config()

# %%
engine = sqlalchemy.create_engine('postgresql://user:pass@host/database',
                        connect_args= sql_config # use dictionary with config details
                        )

# %%
schema = 'capstone_ash'

# %%
# Specify which table within your database you want to push your data to. Give your table an unambiguous name.
table_name = "no2_statewise"
# If the specified table doesn’t exist yet, it will be created
# With ‘replace’, your data will be replaced if the table already exists.
# This may take some time ...
# Write records stored in a dataframe to SQL database
if engine!=None:
  try:
      NO2_state.to_sql(name=table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists="replace", # Drop the table before inserting new values
                        schema=schema, # Use schema that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=10000, # Specify the number of rows in each batch to be written at a time
                        method="multi") # Pass multiple values in a single INSERT clause
      print(f'The {table_name} table was imported successfully.')
    # Error handling
  except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None

# %%
# Specify which table within your database you want to push your data to. Give your table an unambiguous name.
table_name = "co_statewise"
# If the specified table doesn’t exist yet, it will be created
# With ‘replace’, your data will be replaced if the table already exists.
# This may take some time ...
# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        CO_state.to_sql(name=table_name, # Name of SQL table
                         con=engine, # Engine or connection
                        if_exists="replace", # Drop the table before inserting new values
                        schema=schema, # Use schema that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=10000, # Specify the number of rows in each batch to be written at a time
                        method="multi") # Pass multiple values in a single INSERT clause
        print(f'The {table_name} table was imported successfully.')
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The co_statewise table was imported successfully.

# %%
# Specify which table within your database you want to push your data to. Give your table an unambiguous name.
table_name = "oz_statewise"
# If the specified table doesn’t exist yet, it will be created
# With ‘replace’, your data will be replaced if the table already exists.
# This may take some time ...
# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        OZ_state.to_sql(name=table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists="replace", # Drop the table before inserting new values
                        schema=schema, # Use schema that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=10000, # Specify the number of rows in each batch to be written at a time
                        method="multi") # Pass multiple values in a single INSERT clause
        print(f'The {table_name} table was imported successfully.')
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The oz_statewise table was imported successfully.

# %%
# Specify which table within your database you want to push your data to. Give your table an unambiguous name.
table_name = "pm25_statewise"
# If the specified table doesn’t exist yet, it will be created
# With ‘replace’, your data will be replaced if the table already exists.
# This may take some time ...
# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        PM_25_state.to_sql(name=table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists="replace", # Drop the table before inserting new values
                        schema=schema, # Use schema that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=10000, # Specify the number of rows in each batch to be written at a time
                        method="multi") # Pass multiple values in a single INSERT clause
        print(f'The {table_name} table was imported successfully.')
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The pm25_statewise table was imported successfully.

# %%
# Specify which table within your database you want to push your data to. Give your table an unambiguous name.
table_name = "pm10_statewise"
# If the specified table doesn’t exist yet, it will be created
# With ‘replace’, your data will be replaced if the table already exists.
# This may take some time ...
# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        PM_10_state.to_sql(name=table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists="replace", # Drop the table before inserting new values
                        schema=schema, # Use schema that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=10000, # Specify the number of rows in each batch to be written at a time
                        method="multi") # Pass multiple values in a single INSERT clause
        print(f'The {table_name} table was imported successfully.')
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The pm10_statewise table was imported successfully.

# %%
# Specify which table within your database you want to push your data to. Give your table an unambiguous name.
table_name = "so2_statewise"
# If the specified table doesn’t exist yet, it will be created
# With ‘replace’, your data will be replaced if the table already exists.
# This may take some time ...
# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        SO2_state.to_sql(name=table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists="replace", # Drop the table before inserting new values
                        schema=schema, # Use schema that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=10000, # Specify the number of rows in each batch to be written at a time
                        method="multi") # Pass multiple values in a single INSERT clause
        print(f'The {table_name} table was imported successfully.')
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The so2_statewise table was imported successfully.

# %%
# Specify which table within your database you want to push your data to. Give your table an unambiguous name.
table_name = "ca_co"
# If the specified table doesn’t exist yet, it will be created
# With ‘replace’, your data will be replaced if the table already exists.
# This may take some time ...
# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        CA_CO.to_sql(name=table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists="replace", # Drop the table before inserting new values
                        schema=schema, # Use schema that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=10000, # Specify the number of rows in each batch to be written at a time
                        method="multi") # Pass multiple values in a single INSERT clause
        print(f'The {table_name} table was imported successfully.')
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The ca_co table was imported successfully.

# %%
# Specify which table within your database you want to push your data to. Give your table an unambiguous name.
table_name = "ca_no2"
# If the specified table doesn’t exist yet, it will be created
# With ‘replace’, your data will be replaced if the table already exists.
# This may take some time ...
# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        CA_NO2.to_sql(name=table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists="replace", # Drop the table before inserting new values
                        schema=schema, # Use schema that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=10000, # Specify the number of rows in each batch to be written at a time
                        method="multi") # Pass multiple values in a single INSERT clause
        print(f'The {table_name} table was imported successfully.')
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The ca_no2 table was imported successfully.

# %%
# Specify which table within your database you want to push your data to. Give your table an unambiguous name.
table_name = "ca_oz"
# If the specified table doesn’t exist yet, it will be created
# With ‘replace’, your data will be replaced if the table already exists.
# This may take some time ...
# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        CA_OZ.to_sql(name=table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists="replace", # Drop the table before inserting new values
                        schema=schema, # Use schema that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=10000, # Specify the number of rows in each batch to be written at a time
                        method="multi") # Pass multiple values in a single INSERT clause
        print(f'The {table_name} table was imported successfully.')
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The ca_oz table was imported successfully.

# %%
# Specify which table within your database you want to push your data to. Give your table an unambiguous name.
table_name = "ca_pm10"
# If the specified table doesn’t exist yet, it will be created
# With ‘replace’, your data will be replaced if the table already exists.
# This may take some time ...
# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        CA_PM10.to_sql(name=table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists="replace", # Drop the table before inserting new values
                        schema=schema, # Use schema that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=10000, # Specify the number of rows in each batch to be written at a time
                        method="multi") # Pass multiple values in a single INSERT clause
        print(f'The {table_name} table was imported successfully.')
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The ca_pm10 table was imported successfully.

# %%
# Specify which table within your database you want to push your data to. Give your table an unambiguous name.
table_name = "ca_pm25"
# If the specified table doesn’t exist yet, it will be created
# With ‘replace’, your data will be replaced if the table already exists.
# This may take some time ...
# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        CA_PM25.to_sql(name=table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists="replace", # Drop the table before inserting new values
                        schema=schema, # Use schema that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=10000, # Specify the number of rows in each batch to be written at a time
                        method="multi") # Pass multiple values in a single INSERT clause
        print(f'The {table_name} table was imported successfully.')
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The ca_pm25 table was imported successfully.

# %%
# Specify which table within your database you want to push your data to. Give your table an unambiguous name.
table_name = "ca_so2"
# If the specified table doesn’t exist yet, it will be created
# With ‘replace’, your data will be replaced if the table already exists.
# This may take some time ...
# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        CA_SO2_final.to_sql(name=table_name, # Name of SQL table
                       con=engine, # Engine or connection
                       if_exists="replace", # Drop the table before inserting new values
                       schema=schema, # Use schema that was defined earlier
                       index=False, # Write DataFrame index as a column
                       chunksize=10000, # Specify the number of rows in each batch to be written at a time
                       method="multi") # Pass multiple values in a single INSERT clause
        print(f'The {table_name} table was imported successfully.')
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The ca_so2 table was imported successfully.

# %% [markdown]
# #### Visualization using Seaborn

# %%
# Create a line plot 
line_plot = sns.lineplot(x='date', y='daily_max_8-hour_co_concentration', hue='state', data=CO_state)

# Axis labels
line_plot.set_xlabel("Date")
line_plot.set_ylabel("Max 8 Hour CO Concentration")

plt.show()

# %%
# Checking the California CO values
line_plot_CA_CO= sns.lineplot(x='Date', y='Daily Max 8-hour CO Concentration', data=CA_CO)

line_plot_CA_CO.set_xlabel("Date")
line_plot_CA_CO.set_ylabel("Daily Max 8-hour CO Concentration in California")

plt.show()

# %%
line_plot_PM10= sns.lineplot(x='date', y='daily_aqi_value', hue='state', data=PM_10_state)

line_plot_PM10.set_xlabel("Date")
line_plot_PM10.set_ylabel("Daily AQI")

plt.show()

# %%
sns.lineplot(x='date', y='daily_mean_pm2.5_concentration', hue='state', data=PM_25_state)

plt.axhline(y=35, color='r', linestyle='--') #Reference line is the NAAQS permissible limit set for 24 hours

plt.show()

# %% [markdown]
# ### Understanding the data by Calculations

# %%
median_CO = CO_state.groupby('state')['daily_max_8-hour_co_concentration'].median()
median_CO
# Out:
# state
# California      0.4
# Illinois        0.3
# New York        0.3
# Pennsylvania    0.3
# Texas           0.3
# Name: daily_max_8-hour_co_concentration, dtype: float64

# %%
CO_state.describe()
# Out:
#                                 date  daily_max_8-hour_co_concentration  \
# count                         167805                      167805.000000
# mean   2020-05-25 16:17:29.332260864                           0.410188
# min              2018-01-01 00:00:00                          -0.400000
# 25%              2019-02-21 00:00:00                           0.200000
# 50%              2020-05-10 00:00:00                           0.300000
# 75%              2021-08-15 00:00:00                           0.500000
# max              2022-12-31 00:00:00                          12.800000
# std                              NaN                           0.286565
#
#        daily_aqi_value  daily_obs_count  site_latitude  site_longitude
# count    167805.000000    167805.000000  167805.000000   167805.000000
# mean          4.626179        23.349185      36.417385     -107.424565
# min           0.000000         1.000000      27.507904     -124.201390
# ...

# %%
median_SO2 = SO2_state.groupby('state')['daily_max_1-hour_so2_concentration'].median()
median_SO2
# Out:
# state
# California      0.8
# Illinois        1.4
# New York        0.4
# Pennsylvania    1.0
# Texas           0.8
# Name: daily_max_1-hour_so2_concentration, dtype: float64

# %%
PM_10_state.describe()
# Out:
#                                 date  daily_mean_pm10_concentration  \
# count                         206350                  206350.000000
# mean   2020-07-06 00:50:49.855100416                      26.301803
# min              2018-01-01 00:00:00                     -48.000000
# 25%              2019-03-30 00:00:00                      11.000000
# 50%              2020-07-08 00:00:00                      19.000000
# 75%              2021-10-13 00:00:00                      32.000000
# max              2022-12-31 00:00:00                    7681.000000
# std                              NaN                      43.154425
#
#        daily_aqi_value  daily_obs_count  site_latitude  site_longitude
# count    206350.000000    206350.000000  206350.000000   206350.000000
# mean         23.221808         1.010545      36.431878     -113.137094
# min           0.000000         1.000000      26.226343     -124.179490
# 25%          10.000000         1.000000      34.416510     -120.457500
# ...
